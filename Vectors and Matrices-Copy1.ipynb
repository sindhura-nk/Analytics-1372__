# %% [markdown]
# ## Vectors
# A vector is an object that has both a magnitude and a direction. Geometrically, we can picture a vector as a directed line segment, whose length is the magnitude of the vector and with an arrow indicating the direction. The direction of the vector is from its tail to its head.
# ![image.png](attachment:bd541e55-5f09-41d6-b541-fe24b2380aab.png)

# %% [markdown]
# A vector in a simple term can be considered as a single-dimensional array. With respect to Python, a vector is a one-dimensional array of lists. It occupies the elements in a similar manner as that of a Python list.

# %% [markdown]
# ![image.png](attachment:e7c7a819-0228-4880-9240-6893c0d77024.png)

# %%
## Numpy
import numpy as np

# %% [markdown]
# ## to convert coding cell to markdown cell : use keyboard shorcut esc+m or select the cell and press on m
# sum()

# %% [markdown]
# len()

# %% [markdown]
# np.sum()

# %% [markdown]
# ### Lists are 1 dimensional data

# %%
lst_data = [45,67,89]

# %%
str_data = ["Raman","Thaman","Baman"]

# %%
import numpy as np

# %% [markdown]
# ### Syntax:
# numpy.array(list)

# %%
# Horizontal vector
# horz_vec = np.array([10,20,30,40])

# %%
horz_vec = np.array([10,20,30,40])
horz_vec
# Out:
# array([10, 20, 30, 40])

# %%
np.array(lst_data)
# Out:
# array([45, 67, 89])

# %%
# Vertical vector
#ver_vec = np.array([[10],[20],[30],[40]])

# %%
nest_lst = [[10],[20],[45]]
ver_vec = np.array(nest_lst)
ver_vec
# Out:
# array([[10],
#        [20],
#        [45]])

# %%
type(ver_vec)
# Out:
# numpy.ndarray

# %%
# Zero vector
#zero_vec = np.array([0,0,0])

# %%
zer_vec = np.array([0,0,0])
zer_vec
# Out:
# array([0, 0, 0])

# %%
#np.array(0,0,0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 np.array(0,0,0)
#
# TypeError: array() takes from 1 to 2 positional arguments but 3 were given

# %%
# Array/Vector of complex numbers
comp_arr = np.array([1,2,3],dtype="complex")
comp_arr
# Out:
# array([1.+0.j, 2.+0.j, 3.+0.j])

# %%
com_arrays = np.array([1,2,3],dtype="complex")
com_arrays
# Out:
# array([1.+0.j, 2.+0.j, 3.+0.j])

# %%
# Vector of strings
str_arr = np.array(["Raman","Thaman","Suman"])
str_arr
# Out:
# array(['Raman', 'Thaman', 'Suman'], dtype='<U6')

# %%
str_data = np.array(["Naman","Chaman"])
str_data
# Out:
# array(['Naman', 'Chaman'], dtype='<U6')

# %%
# You can access the array elements with indexing 
d1 = np.array([24,56,78,90])
d1
# Out:
# array([24, 56, 78, 90])

# %%
d1[0]
# Out:
# np.int64(24)

# %%
d1[1:]
# Out:
# array([56, 78, 90])

# %%
horz_vec
# Out:
# array([10, 20, 30, 40])

# %%
# Element at 2nd position
horz_vec[1]
# Out:
# np.int64(20)

# %%
horz_vec[1:]
# Out:
# array([20, 30, 40])

# %% [markdown]
# ## Basic Arithmetic Operations

# %%
'''
lst1 = [4,5,6]
lst2 = [3,4,5]
arr1 = np.array(lst1)
arr2 = np.array(lst2)

# Addition of vectors
add_arrs = arr1 + arr2 # output: [7,9,11]

#Subtraction of vectors
sub_arrs = arr1 - arr2 #output: [1,1,1]

#Multiplication of vectors
mul_arrs = arr1 * arr2 #output: [12,20,30]

#Division of vectors
div_arrs = arr1 / arr2 #output: [1.33,1.25,1.2]

#Dot product
dot_arrs = arr1.dot(arr2) #output: 62

# scalar mutliplication
sc = 5
sc_mul = arr1*5 #output: [20,25,30]
'''
# Out:
# '\nlst1 = [4,5,6]\nlst2 = [3,4,5]\narr1 = np.array(lst1)\narr2 = np.array(lst2)\n\n# Addition of vectors\nadd_arrs = arr1 + arr2 # output: [7,9,11]\n\n#Subtraction of vectors\nsub_arrs = arr1 - arr2 #output: [1,1,1]\n\n#Multiplication of vectors\nmul_arrs = arr1 * arr2 #output: [12,20,30]\n\n#Division of vectors\ndiv_arrs = arr1 / arr2 #output: [1.33,1.25,1.2]\n\n#Dot product\ndot_arrs = arr1.dot(arr2) #output: 62\n\n# scalar mutliplication\nsc = 5\nsc_mul = arr1*5 #output: [20,25,30]\n'

# %%
lst1 = [34,56,78]
lst2 = [56,78,90]

# %%
lst1 + lst2
# Out:
# [34, 56, 78, 56, 78, 90]

# %% [markdown]
# ## Arithemetic Operators

# %%
lst1
# Out:
# [34, 56, 78]

# %%
arr1 = np.array(lst1)
arr2 = np.array(lst2)

# %%
type(lst1)
# Out:
# list

# %%
arr1
# Out:
# array([34, 56, 78])

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
# Addition
arr1 + arr2
# Out:
# array([ 90, 134, 168])

# %%
#np.sum(arr1)
# Out:
# np.int64(168)

# %%
#Subtraction
arr1 - arr2
# Out:
# array([-22, -22, -12])

# %%
# Multiplciation
arr1 * arr2
# Out:
# array([1904, 4368, 7020])

# %%
# Division
arr1 / arr2
# Out:
# array([0.60714286, 0.71794872, 0.86666667])

# %%
arr1.dot(arr2)
# Out:
# np.int64(13292)

# %%
np.array([[1],[2],[3]])
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
lst1
# Out:
# [34, 56, 78]

# %%
sum(lst1)
# Out:
# 168

# %%
min(lst1)
# Out:
# 34

# %%
max(lst1)
# Out:
# 78

# %%
np.sum(lst1)
# Out:
# np.int64(168)

# %%
np.min(lst1)
# Out:
# np.int64(34)

# %%
np.mean(arr1)
# Out:
# np.float64(56.0)

# %% [markdown]
# ## Matrix
# A matrix is a two-dimensional data structure where numbers are arranged into rows and columns.
# ![image.png](attachment:f126f36a-d710-423b-830d-3438a68adaea.png)

# %%
d2 = np.array([[1,2,4],[1,2,4]])
d2
# Out:
# array([[1, 2, 4],
#        [1, 2, 4]])

# %%
d3 = np.array([[1,2,3],[1,2,5]])
d3
# Out:
# array([[1, 2, 3],
#        [1, 2, 5]])

# %%
data1 = (124,34,566)

# %%
data = (124,34,566)

# %%
data1
# Out:
# (124, 34, 566)

# %%
d2+d3
# Out:
# array([[2, 4, 7],
#        [2, 4, 9]])
