# %% [markdown]
# ## Dataframe Filter

# %%
import os 
os.chdir("E:\Sindhura\DataSets")
import pandas as pd
start = pd.read_csv("50_Startups.csv")
start.head(2)
# Out:
#         RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.2  136897.80  471784.10    New York  192261.83
# 1  162597.7  151377.59  443898.53  California  191792.06

# %%
car = pd.read_csv("Cars93.csv")
car.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                 NaN  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             56 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %%
car.head(2)
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                 NaN  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
#
#    Turn.circle  Rear.seat.room Luggage.room  Weight   Origin           Make
# 0           37            26.5         11.0    2705  non-USA  Acura Integra
# 1           38            30.0         15.0    3560  non-USA   Acura Legend
#
# [2 rows x 28 columns]

# %% [markdown]
# ## unique() : dataframe[col_name].unique() => returns all the unique data that is present in col_name
# ## nunique() : dataframe.nunique() => number of unique elements present for each column
#     dataframe[col_name].nunique() => number of unique elements present for col_name

# %%
len(car)
# Out:
# 93

# %%
car.nunique()
# Out:
# id                    93
# Manufacturer          32
# Model                 93
# Type                   6
# Min.Price             79
# Price                 81
# Max.Price             79
# MPG.city              21
# MPG.highway           22
# AirBags                2
# DriveTrain             3
# Cylinders              6
# EngineSize            26
# Horsepower            57
# RPM                   24
# Rev.per.mile          78
# Man.trans.avail        2
# Fuel.tank.capacity    38
# Passengers             6
# Length                51
# Wheelbase             27
# Width                 16
# Turn.circle           14
# Rear.seat.room        24
# Luggage.room          16
# Weight                81
# Origin                 2
# Make                  93
# dtype: int64

# %%
car["Type"].nunique()
# Out:
# 6

# %%
car["Type"].unique()
# Out:
# array(['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van'],
#       dtype=object)

# %%
#car.unique()

# %% [markdown]
# ## Scenario1 : Find out cars that belong to Compact Type

# %%
fil1 = car["Type"] == "Compact"
car[fil1]
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 2    3           Audi        90  Compact       25.9   29.1       32.3
# 11  12      Chevrolet  Cavalier  Compact        8.5   13.4       18.3
# 12  13      Chevrolet   Corsica  Compact       11.4   11.4       11.4
# 20  21       Chrysler   LeBaron  Compact       14.5   15.8       17.1
# 24  25          Dodge    Spirit  Compact       11.9   13.3       14.7
# 32  33           Ford     Tempo  Compact       10.4   11.3       12.2
# 42  43          Honda    Accord  Compact       13.8   17.5       21.2
# 54  55          Mazda       626  Compact       14.3   16.5       18.7
# 57  58  Mercedes-Benz      190E  Compact       29.0   31.9       34.9
# 64  65         Nissan    Altima  Compact       13.0   15.7       18.3
# 67  68     Oldsmobile   Achieva  Compact       13.0   13.5       14.0
# 73  74        Pontiac   Sunbird  Compact        9.4   11.1       12.8
# ...

# %% [markdown]
# ## Scenario2: Find out the cars that are priced above 25lakhs

# %%
fil2 = car["Price"]>25
car[fil2]
# Out:
#     id   Manufacturer        Model     Type  Min.Price  Price  Max.Price  \
# 1    2          Acura       Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi           90  Compact       25.9   29.1       32.3
# 3    4           Audi          100  Midsize       30.8   37.7       44.6
# 4    5            BMW         535i  Midsize       23.7   30.0       36.2
# 8    9          Buick      Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac      DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac      Seville  Midsize       37.5   40.1       42.7
# 18  19      Chevrolet     Corvette   Sporty       34.6   38.0       41.5
# 21  22       Chrysler     Imperial    Large       29.5   29.5       29.5
# 27  28          Dodge      Stealth   Sporty       18.5   25.8       33.1
# 47  48       Infiniti          Q45  Midsize       45.4   47.9       50.4
# 48  49          Lexus        ES300  Midsize       27.5   28.0       28.4
# ...

# %% [markdown]
# ## Scenario3: Find out cars that belong to Midsize and are priced between 20-30

# %%
fil3 = car["Type"]=="Midsize" 
fil4 = (car["Price"] >=20) & (car["Price"]<=30)
car[fil3&fil4]
# Out:
#     id Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 4    5          BMW      535i  Midsize       23.7   30.0       36.2        22
# 8    9        Buick   Riviera  Midsize       26.3   26.3       26.3        19
# 36  37         Ford    Taurus  Midsize       15.6   20.2       24.8        21
# 48  49        Lexus     ES300  Midsize       27.5   28.0       28.4        18
# 62  63   Mitsubishi  Diamante  Midsize       22.4   26.1       29.9        18
# 66  67       Nissan    Maxima  Midsize       21.0   21.5       22.0        21
# 92  93        Volvo       850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 4            30         Driver only  ...          4    186        109     69
# 8            27         Driver only  ...          5    198        108     73
# 36           30         Driver only  ...          5    192        106     71
# ...

# %% [markdown]
# ### Display only manufacturer,model,type,price details in the output

# %%
fil3 = car["Type"]=="Midsize" 
fil4 = (car["Price"] >=20) & (car["Price"]<=30)
car[fil3&fil4][["Manufacturer","Model","Type","Price"]]
# Out:
#    Manufacturer     Model     Type  Price
# 4           BMW      535i  Midsize   30.0
# 8         Buick   Riviera  Midsize   26.3
# 36         Ford    Taurus  Midsize   20.2
# 48        Lexus     ES300  Midsize   28.0
# 62   Mitsubishi  Diamante  Midsize   26.1
# 66       Nissan    Maxima  Midsize   21.5
# 92        Volvo       850  Midsize   26.7

# %% [markdown]
# ## Query method is also used for filtering of content
# ### Syntax: dataframe_name.query("col_name conditional statement")
#     1. Always pass the content in double quotes
#     2. column name must NOT be included in quotes
#     3. provide condition and pass the text content in single quotes
#     example: car.query("Type=='Compact'")
#     car.query('Type=="Compact"')

# %%
# find out cars which belong to Compact type
car.query("Type=='Compact'")
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 2    3           Audi        90  Compact       25.9   29.1       32.3
# 11  12      Chevrolet  Cavalier  Compact        8.5   13.4       18.3
# 12  13      Chevrolet   Corsica  Compact       11.4   11.4       11.4
# 20  21       Chrysler   LeBaron  Compact       14.5   15.8       17.1
# 24  25          Dodge    Spirit  Compact       11.9   13.3       14.7
# 32  33           Ford     Tempo  Compact       10.4   11.3       12.2
# 42  43          Honda    Accord  Compact       13.8   17.5       21.2
# 54  55          Mazda       626  Compact       14.3   16.5       18.7
# 57  58  Mercedes-Benz      190E  Compact       29.0   31.9       34.9
# 64  65         Nissan    Altima  Compact       13.0   15.7       18.3
# 67  68     Oldsmobile   Achieva  Compact       13.0   13.5       14.0
# 73  74        Pontiac   Sunbird  Compact        9.4   11.1       12.8
# ...

# %% [markdown]
# ## find out cars which belong provide AirBags to Driver only and have price greater than 25

# %%
car["AirBags"].unique()
# Out:
# array([nan, 'Driver & Passenger', 'Driver only'], dtype=object)

# %%
car.query("(AirBags=='Driver only') & (Price>=25)")
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 2    3           Audi        90  Compact       25.9   29.1       32.3
# 4    5            BMW      535i  Midsize       23.7   30.0       36.2
# 8    9          Buick   Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac   DeVille    Large       33.0   34.7       36.3
# 18  19      Chevrolet  Corvette   Sporty       34.6   38.0       41.5
# 27  28          Dodge   Stealth   Sporty       18.5   25.8       33.1
# 47  48       Infiniti       Q45  Midsize       45.4   47.9       50.4
# 48  49          Lexus     ES300  Midsize       27.5   28.0       28.4
# 56  57          Mazda      RX-7   Sporty       32.5   32.5       32.5
# 57  58  Mercedes-Benz      190E  Compact       29.0   31.9       34.9
# 62  63     Mitsubishi  Diamante  Midsize       22.4   26.1       29.9
# 77  78           Saab       900  Compact       20.3   28.7       37.1
#
# ...

# %%
pd.set_option("display.max_rows",100)
pd.set_option("display.max_columns",29)

# %%
car
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 0    1          Acura         Integra    Small       12.9   15.9       18.8
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi              90  Compact       25.9   29.1       32.3
# 3    4           Audi             100  Midsize       30.8   37.7       44.6
# 4    5            BMW            535i  Midsize       23.7   30.0       36.2
# 5    6          Buick         Century  Midsize       14.2   15.7       17.3
# 6    7          Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8          Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9          Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac         Seville  Midsize       37.5   40.1       42.7
# ...

# %% [markdown]
# ### Sort the data
# ### sort_values() method: ascending order, descending order
#     categorical/text : Asc - A-Z (a-z). Desc- Z-A (z-a)
#     Numerical : Asc: smallest to largest , Desc: Largest to smallest
# ### Syntax: dataframe_name.sort_values(by=[col_name])
# default: ascending order
# ### Syntax: dataframe_name.sort_values(by=[col_name],ascending=False)

# %%
car.head(3)
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
#
#    MPG.highway             AirBags DriveTrain Cylinders  EngineSize  \
# 0           31                 NaN      Front         4         1.8
# 1           25  Driver & Passenger      Front         6         3.2
# 2           26         Driver only      Front         6         2.8
#
#    Horsepower   RPM  Rev.per.mile Man.trans.avail  Fuel.tank.capacity  \
# 0         140  6300          2890             Yes                13.2
# 1         200  5500          2335             Yes                18.0
# 2         172  5500          2280             Yes                16.9
#
#    Passengers  Length  Wheelbase  Width  Turn.circle  Rear.seat.room  \
# ...

# %%
car.sort_values(by=["Price"])
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 30  31           Ford         Festiva    Small        6.9    7.4        7.9
# 43  44        Hyundai           Excel    Small        6.8    8.0        9.2
# 52  53          Mazda             323    Small        7.4    8.3        9.1
# 38  39            Geo           Metro    Small        6.7    8.4       10.0
# 79  80         Subaru           Justy    Small        7.3    8.4        9.5
# 82  83         Suzuki           Swift    Small        7.3    8.6       10.0
# 72  73        Pontiac          LeMans    Small        8.2    9.0        9.9
# 87  88     Volkswagen             Fox    Small        8.7    9.1        9.5
# 22  23          Dodge            Colt    Small        7.9    9.2       10.6
# 83  84         Toyota          Tercel    Small        7.8    9.8       11.8
# 45  46        Hyundai          Scoupe   Sporty        9.1   10.0       11.0
# ...

# %%
car.sort_values(by=["Price"],ascending=True)
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 30  31           Ford         Festiva    Small        6.9    7.4        7.9
# 43  44        Hyundai           Excel    Small        6.8    8.0        9.2
# 52  53          Mazda             323    Small        7.4    8.3        9.1
# 38  39            Geo           Metro    Small        6.7    8.4       10.0
# 79  80         Subaru           Justy    Small        7.3    8.4        9.5
# 82  83         Suzuki           Swift    Small        7.3    8.6       10.0
# 72  73        Pontiac          LeMans    Small        8.2    9.0        9.9
# 87  88     Volkswagen             Fox    Small        8.7    9.1        9.5
# 22  23          Dodge            Colt    Small        7.9    9.2       10.6
# 83  84         Toyota          Tercel    Small        7.8    9.8       11.8
# 45  46        Hyundai          Scoupe   Sporty        9.1   10.0       11.0
# ...

# %%
car.sort_values(by=["Price"],ascending=False)
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 58  59  Mercedes-Benz            300E  Midsize       43.8   61.9       80.0
# 47  48       Infiniti             Q45  Midsize       45.4   47.9       50.4
# 10  11       Cadillac         Seville  Midsize       37.5   40.1       42.7
# 18  19      Chevrolet        Corvette   Sporty       34.6   38.0       41.5
# 3    4           Audi             100  Midsize       30.8   37.7       44.6
# 51  52        Lincoln        Town_Car    Large       34.4   36.1       37.8
# 49  50          Lexus           SC300  Midsize       34.7   35.2       35.6
# 9   10       Cadillac         DeVille    Large       33.0   34.7       36.3
# 50  51        Lincoln     Continental  Midsize       33.3   34.3       35.3
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 56  57          Mazda            RX-7   Sporty       32.5   32.5       32.5
# ...

# %%
car.sort_values(by=["AirBags"])
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 76  77        Pontiac      Bonneville    Large       19.4   24.4       29.4
# 74  75        Pontiac        Firebird   Sporty       14.0   17.7       21.4
# 58  59  Mercedes-Benz            300E  Midsize       43.8   61.9       80.0
# 50  51        Lincoln     Continental  Midsize       33.3   34.3       35.3
# 49  50          Lexus           SC300  Midsize       34.7   35.2       35.6
# 42  43          Honda          Accord  Compact       13.8   17.5       21.2
# 29  30          Eagle          Vision    Large       17.5   19.3       21.2
# 20  21       Chrysler         LeBaron  Compact       14.5   15.8       17.1
# 19  20       Chrylser        Concorde    Large       18.4   18.4       18.4
# 40  41          Honda         Prelude   Sporty       17.0   19.8       22.7
# ...

# %% [markdown]
# ## Scenario : Find out cars whose manufacturer is Pontiac and price is below 25. Sort the output in descending order. Display only Manufacturer and Price details

# %%
fil6 = car["Manufacturer"]=="Pontiac"
fil7 = car["Price"]<=25
car[fil6 & fil7].sort_values(by="Price",ascending=False)[["Manufacturer","Price"]]
# Out:
#    Manufacturer  Price
# 76      Pontiac   24.4
# 75      Pontiac   18.5
# 74      Pontiac   17.7
# 73      Pontiac   11.1
# 72      Pontiac    9.0

# %%
car[(car["Manufacturer"]=="Pontiac")&(car["Price"]<=25)].sort_values(by="Price",ascending=False)[["Manufacturer","Price"]]
# Out:
#    Manufacturer  Price
# 76      Pontiac   24.4
# 75      Pontiac   18.5
# 74      Pontiac   17.7
# 73      Pontiac   11.1
# 72      Pontiac    9.0

# %% [markdown]
# ## Aggregation Functions
#     sum() : df.sum(numeric_only=True)
#             df[col_name].sum()
#     min()
#     max()
#     count() of non null data

# %% [markdown]
# ## What is the overall price of cars

# %%
car["Price"].sum()
# Out:
# np.float64(1814.4)

# %%
car.sum(numeric_only=True)
# Out:
# id                      4371.0
# Min.Price               1592.7
# Price                   1814.4
# Max.Price               2036.6
# MPG.city                2080.0
# MPG.highway             2705.0
# EngineSize               248.1
# Horsepower             13376.0
# RPM                   491100.0
# Rev.per.mile          216895.0
# Fuel.tank.capacity      1549.8
# Passengers               473.0
# Length                 17038.0
# Wheelbase               9667.0
# Width                   6452.0
# Turn.circle             3623.0
# Rear.seat.room          2532.5
# Luggage.room            1139.0
# Weight                285780.0
# dtype: float64

# %%
car.min(numeric_only=True)
# Out:
# id                       1.0
# Min.Price                6.7
# Price                    7.4
# Max.Price                7.9
# MPG.city                15.0
# MPG.highway             20.0
# EngineSize               1.0
# Horsepower              55.0
# RPM                   3800.0
# Rev.per.mile          1320.0
# Fuel.tank.capacity       9.2
# Passengers               2.0
# Length                 141.0
# Wheelbase               90.0
# Width                   60.0
# Turn.circle             32.0
# Rear.seat.room          19.0
# Luggage.room             6.0
# Weight                1695.0
# dtype: float64

# %%
car["Weight"].min()
# Out:
# 1695

# %%
car["Weight"].max()
# Out:
# 4105

# %%
car.max(numeric_only=True)
# Out:
# id                      93.0
# Min.Price               45.4
# Price                   61.9
# Max.Price               80.0
# MPG.city                46.0
# MPG.highway             50.0
# EngineSize               5.7
# Horsepower             300.0
# RPM                   6500.0
# Rev.per.mile          3755.0
# Fuel.tank.capacity      27.0
# Passengers               8.0
# Length                 219.0
# Wheelbase              119.0
# Width                   78.0
# Turn.circle             45.0
# Rear.seat.room          36.0
# Luggage.room            22.0
# Weight                4105.0
# dtype: float64

# %% [markdown]
# ## To calculate aggregated details, you can also use agg()
#     df.agg({col_name:[agg_func]})
#     df.agg({col_name:["sum","min"],col_name2:["sum","min"]})

# %%
car.agg({"Price":["min","max","sum"]})
# Out:
#       Price
# min     7.4
# max    61.9
# sum  1814.4

# %%
car.agg({"Price":["min","max","sum"],
         "Weight":["min","max","sum"]})
# Out:
#       Price  Weight
# min     7.4    1695
# max    61.9    4105
# sum  1814.4  285780

# %%
car.agg({"Price":["mean","std"],
        "Horsepower":["mean","std"]}).round(2)
# Out:
#       Price  Horsepower
# mean  19.51      143.83
# std    9.66       52.37

# %% [markdown]
# ## Groupby
# ## syntax: df.groupby(by=[col_name,col_name2]).aggfunc()[[col_subsetting]]

# %% [markdown]
# ## scenario : Find out min prices for all types of cars

# %%
car.groupby(by=["Type"]).min(numeric_only=True)
# Out:
#          id  Min.Price  Price  Max.Price  MPG.city  MPG.highway  EngineSize  \
# Type
# Compact   3        8.5   11.1       11.4        20           26         2.0
# Large     7       17.5   18.4       18.4        16           25         3.3
# Midsize   2       12.4   13.9       14.9        16           22         2.0
# Small     1        6.7    7.4        7.9        22           29         1.0
# Sporty   14        9.1   10.0       11.0        17           24         1.3
# Van      16       13.6   16.3       18.0        15           20         2.4
#
#          Horsepower   RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  \
# Type
# Compact          96  4200          2090                14.5           4
# Large           147  4000          1320                16.0           6
# Midsize         100  3800          1690                16.0           4
# Small            55  4800          2145                 9.2           4
# ...

# %%
car.groupby(by=["Type"]).min(numeric_only=True)[["Price"]]
# Out:
#          Price
# Type
# Compact   11.1
# Large     18.4
# Midsize   13.9
# Small      7.4
# Sporty    10.0
# Van       16.3

# %% [markdown]
# ## Show the total price of cars on basis of airbags

# %%
car.groupby(by=["AirBags"]).sum(numeric_only=True)
# Out:
#                       id  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# AirBags
# Driver & Passenger   587      331.3  380.1      429.0       276          382
# Driver only         1889      775.0  883.1      991.3       910         1196
#
#                     EngineSize  Horsepower     RPM  Rev.per.mile  \
# AirBags
# Driver & Passenger        45.1        2563   75100         29895
# Driver only              118.8        6380  219050         93865
#
#                     Fuel.tank.capacity  Passengers  Length  Wheelbase  Width  \
# AirBags
# Driver & Passenger               248.7          70    2680       1506   1003
# Driver only                      720.6         211    7770       4395   2935
#
#                     Turn.circle  Rear.seat.room  Luggage.room  Weight
# AirBags
# Driver & Passenger          568           396.5         197.0   47445
# Driver only                1667          1103.0         534.0  133075

# %%
car.groupby(by=["AirBags"]).sum(numeric_only=True)[["Price"]]
# Out:
#                     Price
# AirBags
# Driver & Passenger  380.1
# Driver only         883.1

# %% [markdown]
# ## Show the max price of cars based on type and airbags provided

# %%
car.groupby(by=["Type","AirBags"]).max(numeric_only=True)[["Price"]]
# Out:
#                             Price
# Type    AirBags
# Compact Driver & Passenger   17.5
#         Driver only          31.9
# Large   Driver & Passenger   24.4
#         Driver only          34.7
# Midsize Driver & Passenger   61.9
#         Driver only          47.9
# Small   Driver only          12.1
# Sporty  Driver & Passenger   19.8
#         Driver only          38.0
# Van     Driver only          22.7

# %%
a = car.groupby(by=["Type","AirBags"]).max(numeric_only=True)[["Price"]]
a.columns
# Out:
# Index(['Price'], dtype='object')

# %%
a.columns = ["Max_Price"]

# %%
a
# Out:
#                             Max_Price
# Type    AirBags
# Compact Driver & Passenger       17.5
#         Driver only              31.9
# Large   Driver & Passenger       24.4
#         Driver only              34.7
# Midsize Driver & Passenger       61.9
#         Driver only              47.9
# Small   Driver only              12.1
# Sporty  Driver & Passenger       19.8
#         Driver only              38.0
# Van     Driver only              22.7
